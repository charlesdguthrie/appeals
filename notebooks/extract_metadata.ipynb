# %%
import pandas as pd

# %%
df = pd.read_csv('data/merged_caselevel_data.csv')
judges = df.iloc[:,160:229]

# %%
decisions = df.loc[:,('caseid','casetyp1','geniss','direct1','treat','majvotes','dissent','concur','casetyp2','direct2')]

# %%
df2 = pd.concat([decisions,judges],axis=1)
df2.head()
# Out:
#    caseid  casetyp1  geniss  direct1  treat  majvotes  dissent  concur  \
# 0  X43COQ       202       2        3      6         3        0       0
# 1  X2O3RV       747       7        0      3         3        0       0
# 2  XAFJD8       722       7        2      5         3        0       0
# 3  X4AI87       720       7        3      4         3        0       0
# 4  X3A35E       733       7        0      4         3        0       0
#
#    casetyp2  direct2   ...     j13maj1  j13maj2  codej14  j14vote1  j14vote2  \
# 0       NaN      NaN   ...         NaN      NaN      NaN       NaN       NaN
# 1       760        0   ...         NaN      NaN      NaN       NaN       NaN
# 2       NaN      NaN   ...         NaN      NaN      NaN       NaN       NaN
# 3       NaN      NaN   ...         NaN      NaN      NaN       NaN       NaN
# 4       729        3   ...         NaN      NaN      NaN       NaN       NaN
#
#    j14maj1  j14maj2  codej15  j15vote1  j15vote2
# 0      NaN      NaN      NaN       NaN       NaN
# 1      NaN      NaN      NaN       NaN       NaN
# 2      NaN      NaN      NaN       NaN       NaN
# 3      NaN      NaN      NaN       NaN       NaN
# 4      NaN      NaN      NaN       NaN       NaN
#
# [5 rows x 79 columns]

# %%
df2.to_csv('data/metadata_compact.csv',index=False)
