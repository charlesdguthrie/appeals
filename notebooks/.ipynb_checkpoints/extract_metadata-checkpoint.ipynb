# %%
import pandas as pd

# %%
df = pd.read_csv('data/merged_caselevel_data.csv')
# Out:
# /Users/205341/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1130: DtypeWarning: Columns (10,14,17,235,241,249,250,265,370,375,376,386) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df2 = df.loc[:,('caseid','casetyp1','geniss','direct1','casetyp2','treat','majvotes','dissent','concur')]

# %%
df2
# Out:
#        caseid  casetyp1  geniss  direct1  casetyp2  treat  majvotes  dissent  \
# 0      X43COQ       202       2        3       NaN      6         3        0
# 1      X2O3RV       747       7        0       760      3         3        0
# 2      XAFJD8       722       7        2       NaN      5         3        0
# 3      X4AI87       720       7        3       NaN      4         3        0
# 4      X3A35E       733       7        0       729      4         3        0
# 5      XAFK3N       731       7        1       NaN      1         3        0
# 6      XAFJS6       760       7        3       NaN      1         3        0
# 7      X46B2T       291       2        1       NaN      1         3        0
# 8      XAC0CM       204       2        3       203      5         3        0
# 9      X46CBN       291       2        3       NaN      5         3        0
# 10     X46BDF       740       7        0       728      7         3        0
# ...
